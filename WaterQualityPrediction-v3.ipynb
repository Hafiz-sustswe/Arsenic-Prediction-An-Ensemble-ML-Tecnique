# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import joblib
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, learning_curve

# %%
# Load the final feature engineered data
df_final = pd.read_csv('final_feature_engineered_data.csv')

# %%
# Separate the features and target
X = df_final.drop(columns=['Log_Arsenic'])
y = df_final['Log_Arsenic']

# %%
# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
# Load the best model
best_model = joblib.load('./Saved Models/best_stacking_model.pkl')
# Out:
# c:\Users\Nitro Gaming\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:376: InconsistentVersionWarning: Trying to unpickle estimator SVR from version 1.4.2 when using version 1.5.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\Nitro Gaming\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:376: InconsistentVersionWarning: Trying to unpickle estimator DecisionTreeRegressor from version 1.4.2 when using version 1.5.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\Nitro Gaming\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:376: InconsistentVersionWarning: Trying to unpickle estimator RandomForestRegressor from version 1.4.2 when using version 1.5.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\Nitro Gaming\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:376: InconsistentVersionWarning: Trying to unpickle estimator LinearRegression from version 1.4.2 when using version 1.5.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\Nitro Gaming\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:376: InconsistentVersionWarning: Trying to unpickle estimator StackingRegressor from version 1.4.2 when using version 1.5.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
# Introduction
print("This notebook contains visualizations for the research project.")
# Out:
# This notebook contains visualizations for the research project.

# %% [markdown]
# # Data Overview and Preprocessing

# %%
# Data Distribution
for column in df_final.columns:
    plt.figure(figsize=(10, 6))
    sns.histplot(df_final[column], kde=True)
    
    # Check and replace column names for the title
    if column == 'Bicarb':
        title = 'Bicarbonate'
    elif column == 'Chlor':
        title = 'Chloride'
    else:
        title = column
        
    plt.title(f'Distribution of {title}')
    plt.show()

# %% [markdown]
# ## Correlation Matrix

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(df_final.corr(), annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ## Feature Importance

# %%
feature_importance = best_model.named_estimators_['rf'].feature_importances_
features = df_final.columns[:-1]  # Exclude the target column

# %%
plt.figure(figsize=(12, 6))
plt.barh(features, feature_importance)
plt.title('Feature Importance')
plt.xlabel('Importance')
plt.ylabel('Features')
plt.show()

# %% [markdown]
# # Model Performance Comparison

# %% [markdown]
# ## Load the results DataFrame for individual models

# %%
individual_results_df = pd.read_csv('./model_comparison_results.csv')

# %%
individual_results_df
# Out:
#                                 Unnamed: 0  CV_R2_Score           MAE  \
# 0                        Linear Regression     0.167647  4.561923e-01
# 1                    Polynomial Regression     0.217806  9.128500e-16
# 2                         Ridge Regression     0.317766  4.289743e-01
# 3                         Lasso Regression    -0.311644  8.133298e-01
# 4                   Elastic Net Regression    -0.288568  8.092209e-01
# 5                Support Vector Regression     0.846930  2.720220e-01
# 6                 Decision Tree Regression     0.274752  3.861015e-01
# 7                 Random Forest Regression     0.634661  4.198173e-01
# 8             Gradient Boosting Regression     0.647519  4.061689e-01
# 9           K-Nearest Neighbors Regression    -0.032279  4.831339e-01
# 10                     Bayesian Regression     0.332541  4.352065e-01
# 11               Neural Network Regression     0.377827  4.236287e-01
# 12    Principal Component Regression (PCR)     0.167647  2.062382e-01
# 13  Partial Least Squares Regression (PLS)     0.348971  3.848405e-01
#
#              MSE        R2
# 0   4.337293e-01  0.518584
# 1   1.922848e-30  1.000000
# 2   3.494912e-01  0.612083
# 3   9.699867e-01 -0.076633
# 4   9.534373e-01 -0.058264
# 5   1.931032e-01  0.785666
# 6   6.057940e-01  0.327601
# 7   5.731295e-01  0.363857
# 8   6.423270e-01  0.287051
# 9   6.104306e-01  0.322455
# 10  3.334634e-01  0.629874
# 11  5.357772e-01  0.405316
# 12  7.345748e-02  0.918466
# 13  3.102032e-01  0.655691

# %%
## Create a DataFrame with the performance metrics of the top models
model_performance_individual = individual_results_df[['Unnamed: 0','CV_R2_Score', 'MAE', 'MSE', 'R2']].rename(columns={'Unnamed: 0': 'Model'})

# %%
## Bar plot for MAE (Individual Models)
model_performance_individual.plot(x='Model', y='MAE', kind='bar', legend=False, color='skyblue')
plt.title('Model Comparison - MAE (Individual Models)')
plt.ylabel('Mean Absolute Error')
plt.show()

# %%
## Bar plot for R2 (Individual Models)
model_performance_individual.plot(x='Model', y='R2', kind='bar', legend=False, color='salmon')
plt.title('Model Comparison - R2 (Individual Models)')
plt.ylabel('R2 Score')
plt.show()

# %%
## Bar plot for R2 (Individual Models)
model_performance_individual.plot(x='Model', y='CV_R2_Score', kind='bar', legend=False, color='salmon')
plt.title('Model Comparison - K fold Cross Valiation R2 Score (Individual Models)')
plt.ylabel('Cross Validation R2 Score')
plt.show()

# %% [markdown]
# # Ensemble Model Results

# %% [markdown]
# ## Load the results DataFrame for ensemble models

# %% [markdown]
# # We Have Created ensemble model with 252 different combination of stacking model

# %% [markdown]
# ## And Here We are showing the top 15 ensemble models that performed well

# %%
# Load the DataFrame
ensemble_results_df = pd.read_csv('ensemble_model_comparison_results.csv')

# %%
ensemble_results_df.head()
# Out:
#                       Unnamed: 0  CV_Mean_R2  CV_Std_R2       MAE       MSE  \
# 0     STACKING_LINEAR_WITH_RIDGE    0.081148   0.392351  0.491528  0.381131
# 1       STACKING_LINEAR_WITH_SVR    0.820242   0.140375  0.202634  0.105406
# 2  STACKING_LINEAR_WITH_BAYESIAN    0.013654   0.257066  0.618847  0.556424
# 3        STACKING_LINEAR_WITH_RF    0.741289   0.136416  0.381499  0.481085
# 4        STACKING_LINEAR_WITH_GB    0.740399   0.222841  0.397857  0.615138
#
#          R2
# 0  0.576965
# 1  0.883005
# 2  0.382399
# 3  0.466021
# 4  0.317230

# %%
# Sort the DataFrame by the desired column, for example, 'R2', in descending order
sorted_df = ensemble_results_df.sort_values(by=['R2','CV_Mean_R2'], ascending=False)

# Take the top 15 rows
top_15_df = sorted_df.head(15)


ensemble_results_df = top_15_df

# %%
ensemble_results_df
# Out:
#                                         Unnamed: 0  CV_Mean_R2  CV_Std_R2  \
# 12                     STACKING_LINEAR_WITH_SVR_RF    0.794076   0.183497
# 41      STACKING_LINEAR_WITH_RIDGE_SVR_BAYESIAN_RF    0.639876   0.283577
# 56   STACKING_LINEAR_WITH_RIDGE_SVR_BAYESIAN_RF_GB    0.404885   0.680023
# 31            STACKING_LINEAR_WITH_SVR_BAYESIAN_RF    0.728839   0.282440
# 34                  STACKING_LINEAR_WITH_SVR_RF_GB    0.745078   0.201218
# 51         STACKING_LINEAR_WITH_SVR_BAYESIAN_RF_GB    0.707649   0.298220
# 22               STACKING_LINEAR_WITH_RIDGE_SVR_RF    0.742348   0.262482
# 44            STACKING_LINEAR_WITH_RIDGE_SVR_RF_GB    0.683284   0.281483
# 1                         STACKING_LINEAR_WITH_SVR    0.820242   0.140375
# 58  STACKING_LINEAR_WITH_RIDGE_SVR_BAYESIAN_GB_KNN    0.481916   0.622022
# 53        STACKING_LINEAR_WITH_SVR_BAYESIAN_GB_KNN    0.734577   0.277649
# 46           STACKING_LINEAR_WITH_RIDGE_SVR_GB_KNN    0.674888   0.321960
# 36                 STACKING_LINEAR_WITH_SVR_GB_KNN    0.797483   0.170838
# 23               STACKING_LINEAR_WITH_RIDGE_SVR_GB    0.729805   0.231068
# 21         STACKING_LINEAR_WITH_RIDGE_SVR_BAYESIAN    0.763322   0.177481
#
#          MAE       MSE        R2
# 12  0.182704  0.073791  0.918096
# 41  0.198073  0.078027  0.913394
# 56  0.192374  0.087071  0.903356
# 31  0.213909  0.089995  0.900110
# 34  0.181319  0.091967  0.897922
# 51  0.212961  0.094820  0.894754
# 22  0.224755  0.099006  0.890108
# 44  0.224097  0.100492  0.888459
# 1   0.202634  0.105406  0.883005
# 58  0.253916  0.106512  0.881777
# 53  0.259771  0.108016  0.880108
# 46  0.267960  0.110870  0.876940
# 36  0.272475  0.111563  0.876171
# 23  0.235544  0.113098  0.874467
# 21  0.222941  0.114054  0.873406

# %% [markdown]
# ## Create a DataFrame with the performance metrics of the ensemble models

# %%
model_performance_ensemble = ensemble_results_df[['Unnamed: 0', 'CV_Mean_R2', 'MAE', 'MSE', 'R2']].rename(columns={'Unnamed: 0': 'Model'})

# %% [markdown]
# ## Bar plot for MAE (Ensemble Models)

# %%
model_performance_ensemble.plot(x='Model', y='MAE', kind='bar', legend=False, color='skyblue')
plt.title('Model Comparison - MAE (Ensemble Models)')
plt.ylabel('Mean Absolute Error')
plt.show()

# %% [markdown]
# ## Bar plot for R2 (Ensemble Models)

# %%
model_performance_ensemble.plot(x='Model', y='R2', kind='bar', legend=False, color='salmon')
plt.title('Model Comparison - R2 (Ensemble Models)')
plt.ylabel('R2 Score')
plt.show()

# %%
model_performance_ensemble.plot(x='Model', y='CV_Mean_R2', kind='bar', legend=False, color='salmon')
plt.title('Model Comparison - K-fold Cross Validation R2 (Ensemble Models)')
plt.ylabel('Cross Validation R2 Score')
plt.show()

# %% [markdown]
# # Training Process

# %% [markdown]
# ## Learning Curves

# %%
from sklearn.model_selection import train_test_split, learning_curve, KFold, LeaveOneOut, cross_val_score

## Adjust the number of splits if needed
n_splits = min(5, len(X_train))

if n_splits <= 1:
    cv = LeaveOneOut()
else:
    cv = KFold(n_splits=n_splits)

# %%
train_sizes, train_scores, test_scores = learning_curve(best_model, X_train, y_train, cv=5)
train_mean = np.mean(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
# Out:
# c:\Users\Nitro Gaming\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 5 fits failed out of a total of 25.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# joblib.externals.loky.process_executor._RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "c:\Users\Nitro Gaming\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\externals\loky\process_executor.py", line 463, in _process_worker
#     r = call_item()
#         ^^^^^^^^^^^
#   File "c:\Users\Nitro Gaming\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\externals\loky\process_executor.py", line 291, in __call__
#     return self.fn(*self.args, **self.kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nitro Gaming\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\parallel.py", line 598, in __call__
#     return [func(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nitro Gaming\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\parallel.py", line 129, in __call__
#     return self.function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nitro Gaming\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nitro Gaming\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 1256, in cross_val_predict
#     splits = list(cv.split(X, y, **routed_params.splitter.split))
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nitro Gaming\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_split.py", line 409, in split
#     raise ValueError(
# ValueError: Cannot have number of splits n_splits=5 greater than the number of samples: n_samples=2.
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\Nitro Gaming\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Nitro Gaming\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\ensemble\_stacking.py", line 971, in fit
#     return super().fit(X, y, sample_weight)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nitro Gaming\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nitro Gaming\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\ensemble\_stacking.py", line 264, in fit
#     predictions = Parallel(n_jobs=self.n_jobs)(
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nitro Gaming\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\parallel.py", line 67, in __call__
#     return super().__call__(iterable_with_config)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nitro Gaming\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\parallel.py", line 2007, in __call__
#     return output if self.return_generator else list(output)
#                                                 ^^^^^^^^^^^^
#   File "c:\Users\Nitro Gaming\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\parallel.py", line 1650, in _get_outputs
#     yield from self._retrieve()
#   File "c:\Users\Nitro Gaming\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\parallel.py", line 1754, in _retrieve
#     self._raise_error_fast()
#   File "c:\Users\Nitro Gaming\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\parallel.py", line 1789, in _raise_error_fast
#     error_job.get_result(self.timeout)
#   File "c:\Users\Nitro Gaming\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\parallel.py", line 745, in get_result
#     return self._return_or_raise()
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nitro Gaming\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\parallel.py", line 763, in _return_or_raise
#     raise self._result
# ValueError: Cannot have number of splits n_splits=5 greater than the number of samples: n_samples=2.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)

# %%
plt.figure(figsize=(10, 6))
plt.plot(train_sizes, train_mean, 'o-', color='r', label='Training score')
plt.plot(train_sizes, test_mean, 'o-', color='g', label='Cross-validation score')
plt.title('Learning Curve')
plt.xlabel('Training Size')
plt.ylabel('Score')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# # Ensemble Model Architecture

# %% [markdown]
# ## Diagram of Ensemble Model Architecture

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Create a directed graph
G = nx.DiGraph()

# Add nodes for input, base models, and ensemble step
G.add_node('Input Data')
G.add_node('Linear Regression')
G.add_node('SVR')
G.add_node('Random Forest')
G.add_node('Ensemble Output (Aggregation)')

# Add edges to represent the flow from input to each base model, and then to ensemble step
G.add_edge('Input Data', 'Linear Regression')
G.add_edge('Input Data', 'SVR')
G.add_edge('Input Data', 'Random Forest')
G.add_edge('Linear Regression', 'Ensemble Output (Aggregation)')
G.add_edge('SVR', 'Ensemble Output (Aggregation)')
G.add_edge('Random Forest', 'Ensemble Output (Aggregation)')

# Draw the graph
plt.figure(figsize=(12, 8))
pos = nx.spring_layout(G)  # positions for all nodes
nx.draw(G, pos, with_labels=True, node_size=3000, node_color='lightgreen', font_size=10, arrows=True, arrowstyle='-|>', arrowsize=20)
plt.title('Ensemble Model Architecture')
plt.show()

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# ## Prediction vs. Actual Values

# %%
y_pred = best_model.predict(X_test)

plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred, alpha=0.7)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], 'r--')
plt.xlabel('Actual Arsenic Levels')
plt.ylabel('Predicted Arsenic Levels')
plt.title('Actual vs. Predicted Arsenic Levels')
plt.show()

# %% [markdown]
# ## Residual Plots

# %%
residuals = y_test - y_pred

plt.figure(figsize=(10, 6))
plt.scatter(y_pred, residuals, alpha=0.7)
plt.axhline(y=0, color='r', linestyle='--')
plt.xlabel('Predicted Arsenic Levels')
plt.ylabel('Residuals')
plt.title('Residual Plot')
plt.show()

# %% [markdown]
# ## Error Distribution

# %%
plt.figure(figsize=(10, 6))
sns.histplot(residuals, kde=True)
plt.title('Distribution of Prediction Errors')
plt.xlabel('Error')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Model Explaliner

# %%
import shap

svr_model = best_model.named_estimators_['svr']
explainer_svr = shap.Explainer(svr_model, X_train)
shap_values_svr = explainer_svr(X_test)

shap.summary_plot(shap_values_svr, X_test, feature_names=features, title="SHAP Summary Plot for SVR Model")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[66], line 4
#       1 import shap
#       3 svr_model = best_model.named_estimators_['svr']
# ----> 4 explainer_svr = shap.Explainer(svr_model, X_train)
#       5 shap_values_svr = explainer_svr(X_test)
#       7 shap.summary_plot(shap_values_svr, X_test, feature_names=features, title="SHAP Summary Plot for SVR Model")
#
# File c:\Users\Nitro Gaming\AppData\Local\Programs\Python\Python312\Lib\site-packages\shap\explainers\_explainer.py:174, in Explainer.__init__(self, model, masker, link, algorithm, output_names, feature_names, linearize_link, seed, **kwargs)
#     170             algorithm = "permutation"
#     172     # if we get here then we don't know how to handle what was given to us
#     173     else:
# --> 174         raise TypeError("The passed model is not callable and cannot be analyzed directly with the given masker! Model: " + str(model))
#     176 # build the right subclass
#     177 if algorithm == "exact":
#
# TypeError: The passed model is not callable and cannot be analyzed directly with the given masker! Model: SVR(C=10)

# %% [markdown]
# # Geo Statistical Information

# %%
# Out:
#          Day         Month          Year  Conc. Of  pH        EC    Bicarb  \
# 0   0.213766  1.110223e-16 -8.881784e-16      0.181918  0.529605  0.937836
# 1   0.198689  1.110223e-16 -8.881784e-16      0.189731  0.521134  0.922757
# 2   0.194115  1.110223e-16 -8.881784e-16      0.203582  0.512210  0.953746
# 3   0.204799  1.110223e-16 -8.881784e-16      0.191872  0.549472  0.960658
# 4   1.389907  1.110223e-16 -8.881784e-16     -0.409650 -0.473947 -0.564241
# 5   1.389169  1.110223e-16 -8.881784e-16     -0.326212 -0.507226 -0.535738
# 6   1.411476  1.110223e-16 -8.881784e-16     -0.329115 -0.501720 -0.586776
# 7   1.402605  1.110223e-16 -8.881784e-16     -0.344410 -0.471387 -0.567157
# 8   1.403965  1.110223e-16 -8.881784e-16     -0.961438 -0.985865 -0.578515
# 9   1.443295  1.110223e-16 -8.881784e-16     -1.030846 -0.980619 -0.570541
# 10  1.348919  1.110223e-16 -8.881784e-16     -0.987501 -1.009261 -0.564257
# 11  1.413506  1.110223e-16 -8.881784e-16     -0.980599 -0.977828 -0.536462
# 12 -1.191048  1.110223e-16 -8.881784e-16      0.742132  0.722244 -0.551269
# 13 -1.163172  1.110223e-16 -8.881784e-16      0.765892  0.766761 -0.572920
# 14 -1.148418  1.110223e-16 -8.881784e-16      0.714796  0.699271 -0.543553
# 15 -1.139837  1.110223e-16 -8.881784e-16      0.772794  0.745214 -0.602549
# 16  0.216617  1.110223e-16 -8.881784e-16      1.442548 -1.181108 -0.547141
# 17  0.224547  1.110223e-16 -8.881784e-16      1.524893 -1.220027 -0.610562
# 18  0.204835  1.110223e-16 -8.881784e-16      1.480022 -1.204236 -0.546412
# 19  0.176050  1.110223e-16 -8.881784e-16      1.443563 -1.194565 -0.568110
# 20  0.176482  1.110223e-16 -8.881784e-16      1.484093 -1.150029 -0.490397
# 21 -1.648966  1.110223e-16 -8.881784e-16     -2.492794  1.620694  0.968468
# 22 -1.648966  1.110223e-16 -8.881784e-16     -0.910556  0.061813  0.968468
# 23 -1.648966  1.110223e-16 -8.881784e-16     -1.474684  1.511905  0.968468
# 24 -1.156934  1.110223e-16 -8.881784e-16     -1.727366  2.376656  2.316229
# 25 -1.156934  1.110223e-16 -8.881784e-16     -0.972938 -0.380401  0.968468
# 26 -1.156934  1.110223e-16 -8.881784e-16      0.321770  0.315978  2.316229
# 27 -1.156934  1.110223e-16 -8.881784e-16      0.806712  0.284894  0.968468
# 28 -1.156934  1.110223e-16 -8.881784e-16      0.746339  0.703670 -0.558956
# 29 -0.685845  1.110223e-16 -8.881784e-16     -0.106261  1.169755 -0.558956
# 30 -0.685845  1.110223e-16 -8.881784e-16     -0.290777  1.090550 -0.558956
# 31 -0.685845  1.110223e-16 -8.881784e-16      0.199831  1.375127  0.968468
# 32  0.200140  1.110223e-16 -8.881784e-16      1.466277 -0.710772 -2.321421
# 33  0.200140  1.110223e-16 -8.881784e-16     -0.414149 -0.983449  0.968468
# 34  0.200140  1.110223e-16 -8.881784e-16     -0.910556 -0.864792 -0.558956
# 35  0.200140  1.110223e-16 -8.881784e-16      1.466277 -1.187583 -0.558956
# 36  0.200140  1.110223e-16 -8.881784e-16     -1.537740 -0.598246  0.968468
# 37  0.200140  1.110223e-16 -8.881784e-16      0.260836 -0.344985  0.968468
# 38  0.200140  1.110223e-16 -8.881784e-16      0.927251  2.314296 -2.321421
# 39  0.200140  1.110223e-16 -8.881784e-16      0.199831  0.528402  0.968468
# 40  1.408857  1.110223e-16 -8.881784e-16     -0.352427 -0.488156 -0.558956
# 41  1.408857  1.110223e-16 -8.881784e-16     -0.972938 -0.983449 -0.558956
#
#        Chlor      Iron  Manganese    Sodium  Potassium  Magnesium  Log_Arsenic
# 0  -0.897475 -0.332173  -0.199134 -0.990882  -0.718107   0.459290     2.712108
# 1  -0.903200 -0.345305  -0.198272 -0.970444  -0.688951   0.477924     2.704008
# 2  -0.860840 -0.374221  -0.185931 -0.971685  -0.696098   0.463224     2.671262
# 3  -0.921168 -0.368752  -0.218919 -0.977194  -0.670931   0.455944     2.705551
# 4  -1.396437 -0.353426  -0.788518 -1.319128   0.775543  -0.114794     2.811246
# 5  -1.405846 -0.380960  -0.752810 -1.323950   0.745343  -0.129277     2.864956
# 6  -1.402391 -0.333524  -0.767888 -1.328753   0.806713  -0.082678     2.827142
# 7  -1.447269 -0.383242  -0.785012 -1.349649   0.768426  -0.097811     2.847875
# 8   0.501863  0.153439  -0.944401  0.111024  -1.265145   0.378072     3.250715
# 9   0.514483  0.135911  -0.975615  0.153014  -1.301238   0.385498     3.235086
# 10  0.500792  0.116623  -0.960404  0.108902  -1.306280   0.404702     3.283278
# 11  0.554115  0.160662  -0.945686  0.142984  -1.325308   0.406172     3.241119
# 12  0.298711 -0.231366   0.086939  1.385282  -0.790186   0.511498     3.298366
# 13  0.248559 -0.290601   0.124875  1.418864  -0.782977   0.490790     3.230656
# 14  0.316503 -0.267457   0.089889  1.387848  -0.831066   0.518893     3.259957
# 15  0.321087 -0.225028   0.104677  1.387150  -0.807854   0.515434     3.249262
# 16 -0.492377 -0.176832   0.877526 -0.718272  -0.254101  -0.339829     4.245306
# 17 -0.460338 -0.153983   0.833477 -0.699742  -0.253327  -0.309917     4.265209
# 18 -0.415926 -0.189666   0.831714 -0.710541  -0.255480  -0.349488     4.247390
# 19 -0.500286 -0.205625   0.816156 -0.731213  -0.279034  -0.346970     4.236032
# 20 -0.412671 -0.211854   0.847092 -0.735555  -0.271758  -0.345410     4.255993
# 21  2.213489  1.216120   0.605988  0.736430   1.313136   1.214296     1.386294
# 22  1.875330  2.533678   1.498620  0.865038  -0.056871   1.368144     1.945910
# 23  0.163654  1.911760   3.888941 -0.097930  -0.210933   0.953491     2.079442
# 24 -1.004502 -1.149010   1.386235 -0.648833   1.196789   1.608201     1.098612
# 25  0.628290  2.370488  -0.274624  1.795109   0.376643   1.007188     1.609438
# 26  0.966982 -1.301602  -1.178592  1.986566  -0.483373   1.375757     1.945910
# 27 -0.131904 -1.099014  -0.431062  2.115548   2.055641   1.411283     1.609438
# 28  0.300733 -0.265015   0.112192  1.397733  -0.814273   0.510234     3.258097
# 29  0.361073 -1.405577  -0.152641 -0.172895   1.615090  -2.015707     1.609438
# 30  0.945695 -0.094729  -1.919036  0.262016  -1.255074  -2.109886     1.098612
# 31  2.528674 -0.621152  -0.964301  1.150713   1.669452  -2.164018     1.945910
# 32  1.315407  3.496431   0.054447  0.256990   1.313136  -2.417841     1.791759
# 33  1.281093 -1.301602   1.542931  0.503957  -0.056871  -1.787148     1.098612
# 34  1.281093 -0.052918   0.197674  0.290378   0.510738  -1.818107     1.609438
# 35 -0.452516 -0.179255   0.837001 -0.722203  -0.263225  -0.333494     4.262680
# 36 -0.927457 -0.951530  -0.791968 -0.231250   1.965466   0.210747     2.397895
# 37 -0.526058  0.976312  -0.243870 -0.131073   1.953598  -0.814552     2.484907
# 38 -0.775083  0.726297   0.911872 -0.455558  -0.210933  -0.313233     2.197225
# 39 -0.910414 -0.352046  -0.213290 -0.975926  -0.687144   0.467966     2.708050
# 40 -1.398669 -0.352046  -0.791968 -1.321218   0.774710  -0.113919     2.833213
# 41  0.525199  0.151788  -0.964301  0.128349  -1.303884   0.409331     3.258097

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# Load the data with latitude and longitude
gdf = gpd.GeoDataFrame(df_final, geometry=gpd.points_from_xy(df_final.Lon, df_final.Lat))

# Plot geospatial distribution
fig, ax = plt.subplots(figsize=(12, 8))
gdf.plot(column='Predicted_Arsenic_Level', ax=ax, legend=True, cmap='coolwarm')
plt.title('Geospatial Distribution of Predicted Arsenic Levels')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18548\1967802290.py in ?()
#       1 import geopandas as gpd
#       2 import matplotlib.pyplot as plt
#       3
#       4 # Load the data with latitude and longitude
# ----> 5 gdf = gpd.GeoDataFrame(df_final, geometry=gpd.points_from_xy(df_final.Lon, df_final.Lat))
#       6
#       7 # Plot geospatial distribution
#       8 fig, ax = plt.subplots(figsize=(12, 8))
#
# c:\Users\Nitro Gaming\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Lon'
